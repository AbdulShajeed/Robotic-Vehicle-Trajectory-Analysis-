# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulShajeed/Robotic-Vehicle-Trajectory-Analysis-/blob/main/Robotic_Vehicle_Trajectory_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns  
import os
#cwd = os.getcwd()
#dir_list = os.listdir(cwd)
#print(dir_list)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv("/content/drive/MyDrive/FinalData.csv")

# %%
df
# Out:
#      ACC X  ACC Y  ACC Z  Angle X  Angle Y  Angle Z            Status
# 0     0.01   0.00   1.00     0.02    -0.08    -4.98          STRAIGHT
# 1     0.17   0.23   1.10     0.13    -0.88    -2.65          STRAIGHT
# 2    -0.59  -2.01   1.37    -3.33    -4.98    -7.04          STRAIGHT
# 3    -0.73  -1.45   1.45     0.93    -4.24    -2.31          STRAIGHT
# 4    -0.09   0.27   1.16     0.09    -0.49     0.07          STRAIGHT
# ..     ...    ...    ...      ...      ...      ...               ...
# 894   0.00   0.00   1.00     0.11     0.26     7.81  Un-even surface
# 895   0.01   0.00   0.99    -0.06     0.04     8.26  Un-even surface
# 896   0.00  -0.01   1.00    -0.08    -0.18     8.71  Un-even surface
# 897   0.01  -0.01   1.00    -0.04     0.03     9.16  Un-even surface
# 898   0.01   0.00   1.00    -0.05     0.07     9.61  Un-even surface
#
# [899 rows x 7 columns]

# %%
shuffled_df = df.sample(frac=1.0, random_state=42)

# %%
shuffled_df
# Out:
#      ACC X  ACC Y  ACC Z  Angle X  Angle Y  Angle Z                    Status
# 332   0.00   0.00   1.00     0.42    -0.01   120.77                      LEFT
# 811   0.01   0.00   1.00    -0.25     5.02    -0.02          Un-even surface
# 744   0.00   0.01   1.01     0.25    -0.15    -1.78  Bump only on left wheel
# 244   0.00  -0.01   1.00    -0.28     0.18   -93.89                     RIGHT
# 39    0.02   0.38   0.72    -0.63    -5.58    10.55                  STRAIGHT
# ..     ...    ...    ...      ...      ...      ...                       ...
# 106  -0.35   1.34   0.88     0.62    -2.20    10.64                  STRAIGHT
# 270   0.57  -0.56   0.89     0.93    -4.14   -63.55                     RIGHT
# 860   0.00   0.00   1.00    -0.36     0.20    -0.31          Un-even surface
# 435   0.00  -0.01   0.99    -0.43     0.61    -0.04                    U-TURN
# 102  -0.17   0.13   0.54    -1.06     0.17    -6.22                  STRAIGHT
#
# [899 rows x 7 columns]

# %%
shuffled_df.shape
# Out:
# (899, 7)

# %%
shuffled_df.columns
# Out:
# Index(['ACC X', 'ACC Y', 'ACC Z', 'Angle X', 'Angle Y', 'Angle Z', 'Status'], dtype='object')

# %%
shuffled_df.head()
# Out:
#      ACC X  ACC Y  ACC Z  Angle X  Angle Y  Angle Z                    Status
# 332   0.00   0.00   1.00     0.42    -0.01   120.77                      LEFT
# 811   0.01   0.00   1.00    -0.25     5.02    -0.02          Un-even surface
# 744   0.00   0.01   1.01     0.25    -0.15    -1.78  Bump only on left wheel
# 244   0.00  -0.01   1.00    -0.28     0.18   -93.89                     RIGHT
# 39    0.02   0.38   0.72    -0.63    -5.58    10.55                  STRAIGHT

# %%
sns.FacetGrid(df, hue='Status', height=4)\
    .map(sns.distplot, "ACC X")\
    .add_legend()
    
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.FacetGrid(df, hue='Status', height=4)\
    .map(sns.distplot, "ACC Y")\
    .add_legend()
    
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.FacetGrid(df, hue='Status', height=4)\
    .map(sns.distplot, "ACC Z")\
    .add_legend()
    
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.FacetGrid(df, hue='Status', height=4)\
    .map(sns.distplot, "Angle X")\
    .add_legend()
    
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.FacetGrid(df, hue='Status', height=4)\
    .map(sns.distplot, "Angle Y")\
    .add_legend()
    
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.FacetGrid(df, hue='Status', height=4)\
    .map(sns.distplot, "Angle Z")\
    .add_legend()
    
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
#identifiying outliers 
df.boxplot(by="Status", figsize=(45, 34))
# Out:
# array([[<Axes: title={'center': 'ACC X'}, xlabel='[Status]'>,
#         <Axes: title={'center': 'ACC Y'}, xlabel='[Status]'>],
#        [<Axes: title={'center': 'ACC Z'}, xlabel='[Status]'>,
#         <Axes: title={'center': 'Angle X'}, xlabel='[Status]'>],
#        [<Axes: title={'center': 'Angle Y'}, xlabel='[Status]'>,
#         <Axes: title={'center': 'Angle Z'}, xlabel='[Status]'>]],
#       dtype=object)

# %%
shuffled_df
# Out:
#      ACC X  ACC Y  ACC Z  Angle X  Angle Y  Angle Z                    Status
# 332   0.00   0.00   1.00     0.42    -0.01   120.77                      LEFT
# 811   0.01   0.00   1.00    -0.25     5.02    -0.02          Un-even surface
# 744   0.00   0.01   1.01     0.25    -0.15    -1.78  Bump only on left wheel
# 244   0.00  -0.01   1.00    -0.28     0.18   -93.89                     RIGHT
# 39    0.02   0.38   0.72    -0.63    -5.58    10.55                  STRAIGHT
# ..     ...    ...    ...      ...      ...      ...                       ...
# 106  -0.35   1.34   0.88     0.62    -2.20    10.64                  STRAIGHT
# 270   0.57  -0.56   0.89     0.93    -4.14   -63.55                     RIGHT
# 860   0.00   0.00   1.00    -0.36     0.20    -0.31          Un-even surface
# 435   0.00  -0.01   0.99    -0.43     0.61    -0.04                    U-TURN
# 102  -0.17   0.13   0.54    -1.06     0.17    -6.22                  STRAIGHT
#
# [899 rows x 7 columns]

# %%
#understanding the correlation between columns:
shuffled_df['label'] = 0
shuffled_df['label'].mask(shuffled_df['Status']=='LEFT', 1, inplace=True)
shuffled_df['label'].mask(shuffled_df['Status']=='STRAIGHT', 2, inplace=True)
shuffled_df.corr()
# Out:
# <ipython-input-226-05642723b0bb>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   shuffled_df.corr()
#             ACC X     ACC Y     ACC Z   Angle X   Angle Y   Angle Z     label
# ACC X    1.000000 -0.120388 -0.277483  0.057215 -0.060592  0.019551 -0.026369
# ACC Y   -0.120388  1.000000  0.021067  0.151686  0.010976  0.061358 -0.052704
# ACC Z   -0.277483  0.021067  1.000000 -0.172143  0.364345 -0.084672  0.089002
# Angle X  0.057215  0.151686 -0.172143  1.000000 -0.134465 -0.041446 -0.167296
# Angle Y -0.060592  0.010976  0.364345 -0.134465  1.000000 -0.191193 -0.029133
# Angle Z  0.019551  0.061358 -0.084672 -0.041446 -0.191193  1.000000  0.176793
# label   -0.026369 -0.052704  0.089002 -0.167296 -0.029133  0.176793  1.000000

# %%
sns.pairplot(df,hue="Status")

# %%
Y = shuffled_df['label']
specs = df['Status']
X = shuffled_df.drop(["label", "Status"], axis="columns")
from sklearn.model_selection import train_test_split 
accuracy_data=[]
#, random_state=42
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.10, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics 

clf = LogisticRegression()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy_data.append({"name":"Logistic Regression","accuracy":metrics.accuracy_score(y_test, y_pred)})
print(metrics.accuracy_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# 0.7222222222222222
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85        68
#            1       0.00      0.00      0.00        12
#            2       0.00      0.00      0.00        10
#
#     accuracy                           0.72        90
#    macro avg       0.25      0.32      0.28        90
# weighted avg       0.58      0.72      0.64        90
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.svm import SVC
model = SVC(C=72)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy_data.append({"name":"SVM","accuracy":metrics.accuracy_score(y_test, y_pred)})
print(metrics.accuracy_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# 0.8444444444444444
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90        68
#            1       0.80      0.67      0.73        12
#            2       1.00      0.20      0.33        10
#
#     accuracy                           0.84        90
#    macro avg       0.88      0.61      0.65        90
# weighted avg       0.86      0.84      0.82        90

# %%
print(model.score(x_test, y_test))
# Out:
# 0.8444444444444444

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=2)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=2)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
accuracy_data.append({"name":"Random Forest","accuracy":metrics.accuracy_score(y_test, y_pred)})
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        68
#            1       0.60      0.50      0.55        12
#            2       0.71      0.50      0.59        10
#
#     accuracy                           0.83        90
#    macro avg       0.73      0.65      0.68        90
# weighted avg       0.82      0.83      0.82        90

# %%
rf = RandomForestClassifier(random_state =42, n_jobs=-1 )
params = {'max_depth': range(1,10),
          'min_samples_leaf': range(1,10),
          'n_estimators': range(1,25)}

# %%
from sklearn.model_selection import GridSearchCV
grid_search  =GridSearchCV(estimator = rf,
                           param_grid=params,
                           cv = 4, verbose =3)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# [CV 1/4] END max_depth=4, min_samples_leaf=2, n_estimators=23;, score=0.778 total time=   0.1s
# [CV 2/4] END max_depth=4, min_samples_leaf=2, n_estimators=23;, score=0.767 total time=   0.1s
# [CV 3/4] END max_depth=4, min_samples_leaf=2, n_estimators=23;, score=0.767 total time=   0.1s
# [CV 4/4] END max_depth=4, min_samples_leaf=2, n_estimators=23;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=4, min_samples_leaf=2, n_estimators=24;, score=0.783 total time=   0.1s
# [CV 2/4] END max_depth=4, min_samples_leaf=2, n_estimators=24;, score=0.762 total time=   0.1s
# [CV 3/4] END max_depth=4, min_samples_leaf=2, n_estimators=24;, score=0.777 total time=   0.1s
# [CV 4/4] END max_depth=4, min_samples_leaf=2, n_estimators=24;, score=0.752 total time=   0.1s
# [CV 1/4] END max_depth=4, min_samples_leaf=3, n_estimators=1;, score=0.709 total time=   0.0s
# ...

# %%
rf = RandomForestClassifier(random_state =42, n_jobs=-1 )
params = {'max_depth': range(1,10),
          'min_samples_leaf': range(1,10),
          'n_estimators': range(1,25)}

# %%
# Print the best hyperparameters found
print(grid_search.best_params_)

# Print the classification report for the best estimator
best_estimator = grid_search.best_estimator_
y_pred = best_estimator.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
accuracy_data.append({"name":"Grid Search CV","accuracy":metrics.accuracy_score(y_test, y_pred)})
# Out:
# {'max_depth': 8, 'min_samples_leaf': 2, 'n_estimators': 16}
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        68
#            1       0.80      0.67      0.73        12
#            2       0.62      0.50      0.56        10
#
#     accuracy                           0.84        90
#    macro avg       0.77      0.70      0.73        90
# weighted avg       0.84      0.84      0.84        90

# %%
from sklearn.ensemble import BaggingClassifier
bagging = BaggingClassifier(n_estimators=100, random_state=42)
bagging.fit(x_train, y_train)
y_pred = bagging.predict(x_test)
accuracy_data.append({"name":"Bagging Classifier","accuracy":metrics.accuracy_score(y_test, y_pred)})
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91        68
#            1       0.67      0.67      0.67        12
#            2       0.67      0.60      0.63        10
#
#     accuracy                           0.84        90
#    macro avg       0.74      0.73      0.73        90
# weighted avg       0.84      0.84      0.84        90

# %%
print(accuracy_data)
xaxis = [sub['name'] for sub in accuracy_data ]
yaxis = [ sub['accuracy'] for sub in accuracy_data ]
plt.plot(xaxis,yaxis)  # Plot the chart
plt.ylim(0, 1)
plt.show()  

fig, ax = plt.subplots()
width = 0.4

ax.bar(xaxis, yaxis, width, color = "green")
rects = ax.patches
for i, v in zip(rects,yaxis):
    height = i.get_height()
    ax.text( i.get_x() + i.get_width() / 2, height, str(round(v,2)), ha="center", va="bottom")
plt.show()
# Out:
# [{'name': 'Logistic Regression', 'accuracy': 0.7222222222222222}, {'name': 'SVM', 'accuracy': 0.8444444444444444}, {'name': 'Random Forest', 'accuracy': 0.8333333333333334}, {'name': 'Grid Search CV', 'accuracy': 0.8444444444444444}, {'name': 'Bagging Classifier', 'accuracy': 0.8444444444444444}]
